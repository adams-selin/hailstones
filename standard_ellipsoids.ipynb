# %% [markdown]
# # Code to generate reference 3D ellipsoid STL files for printing/measurements

# %%
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pyvista as pv
import trimesh
from copy import deepcopy
import pymeshfix as mf
# %matplotlib widget

# %% [markdown]
# ## Now generate different ellipsoids

# %%
#Use pyvista to generate an oblate spheroid. Increase u_res, v_res, w_res will increase file size.
#https://docs.pyvista.org/api/utilities/_autosummary/pyvista.parametricellipsoid
ellipsoid_surf_x3y5z2 = pv.ParametricEllipsoid(xradius = 30, yradius=50, zradius=20)
ellipsoid_surf_x3y3z2 = pv.ParametricEllipsoid(xradius = 30, yradius=30, zradius=20)
ellipsoid_surf_x3y3z3 = pv.ParametricEllipsoid(xradius = 30, yradius=30, zradius=30)

ellipsoid_surf_x2y4z1 = pv.ParametricEllipsoid(xradius = 20, yradius=40, zradius=10)
ellipsoid_surf_x2y2z1 = pv.ParametricEllipsoid(xradius = 20, yradius=20, zradius=10)


#triangulate
ellipsoid_surf_x3y5z2 = ellipsoid_surf_x3y5z2.triangulate()
ellipsoid_surf_x3y3z2 = ellipsoid_surf_x3y3z2.triangulate()
ellipsoid_surf_x3y3z3 = ellipsoid_surf_x3y3z3.triangulate()

ellipsoid_surf_x2y4z1 = ellipsoid_surf_x2y4z1.triangulate()
ellipsoid_surf_x2y2z1 = ellipsoid_surf_x2y2z1.triangulate()

# %% [markdown]
# ## Plot the results

# %%
pl = pv.Plotter(shape=(1, 2))
pl.subplot(0, 0)
_ = pl.add_mesh(ellipsoid_surf_x3y5z2,color='blue')
pl.subplot(0, 1)
_ = pl.add_mesh(ellipsoid_surf_x2y2z1 ,color='blue')
pl.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pl = pv.Plotter(shape=(1, 2))
#       2 pl.subplot(0, 0)
#       3 _ = pl.add_mesh(ellipsoid_surf_x3y5z2,color='blue')
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/miniconda3/envs/3dvis/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/miniconda3/envs/3dvis/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File ~/miniconda3/envs/3dvis/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/3dvis/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Write stuff out

# %%
ellipsoid_surf_x3y5z2.save('ellipsoid_surf_x3y5z2.stl')
ellipsoid_surf_x3y3z2.save('ellipsoid_surf_x3y3z2.stl')
ellipsoid_surf_x3y3z3.save('ellipsoid_surf_x3y3z3.stl')

ellipsoid_surf_x2y4z1.save('ellipsoid_surf_x2y4z1.stl')
ellipsoid_surf_x2y2z1.save('ellipsoid_surf_x2y2z1.stl')
